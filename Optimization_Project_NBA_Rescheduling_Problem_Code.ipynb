# %%
import pandas as pd

from collections import defaultdict

import gurobipy as gp
from gurobipy import Model, GRB, quicksum, Env

import re
from math import ceil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/IEOR4004 Project 2/games.csv')

# %%
# check the dataframe
df.head()
# Out:
#                 Date                Visitor  PTS                Home  PTS.1  \
# 0  Sat, Nov 01, 2025  Golden State Warriors  NaN      Boston Celtics    NaN
# 1  Sat, Nov 01, 2025     Los Angeles Lakers  NaN     New York Knicks    NaN
# 2  Sat, Nov 01, 2025         Denver Nuggets  NaN       Brooklyn Nets    NaN
# 3  Sat, Nov 01, 2025           Phoenix Suns  NaN  Philadelphia 76ers    NaN
# 4  Sat, Nov 01, 2025        Houston Rockets  NaN     Toronto Raptors    NaN
#
#   Attend.      LOG                  Arena Notes
# 0  19,000  7:30 PM              TD Garden   NaN
# 1  19,400  7:30 PM  Madison Square Garden   NaN
# 2  17,500  7:30 PM        Barclays Center   NaN
# 3  19,650  7:30 PM     Wells Fargo Center   NaN
# 4  19,600  7:30 PM       Scotiabank Arena   NaN

# %%
# Standardize the column names
needed_map = {
    "Date": "date",
    "Visitor": "away_team",
    "Home": "home_team",
}
df = df.rename(columns=needed_map)

# %%
# Check how many times are there in a day
df['LOG'].unique()
# Out:
# array(['7:30 PM'], dtype=object)

# %%
# Parse dates
df["date"] = pd.to_datetime(df["date"], errors="raise").dt.date

# Normalize team names
df["home_team"] = df["home_team"].astype(str).str.strip()
df["away_team"] = df["away_team"].astype(str).str.strip()
teams = sorted(set(df["home_team"]) | set(df["away_team"]))

# %%
# (a) all dates when team i played home
home_dates = {
    i: sorted(set(df.loc[df["home_team"] == i, "date"]))
    for i in teams
}

# (b) for each team j, the number of times team i played against team j at home
home_vs_count = {i: defaultdict(int) for i in teams}
for _, row in df.iterrows():
    i = row["home_team"]
    j = row["away_team"]
    if i != j:
        home_vs_count[i][j] += 1

# (c) for each team j, the number of times team i played against team j away (i at j’s home)
#     This equals the number of times j hosted i
away_vs_count = {i: defaultdict(int) for i in teams}
for _, row in df.iterrows():
    host = row["home_team"]
    guest = row["away_team"]
    if host != guest:
        away_vs_count[guest][host] += 1

# (d) all the dates when team j played away
away_dates = {
    i: sorted(set(df.loc[df["away_team"] == i, "date"]))
    for i in teams
}

# %% [markdown]
# ## Part 1
#
# Print information for each team

# %%
def print_team_summary(i):
    print(f"\nTEAM: {i}")
    # (a)
    print("(a) Home dates:")
    print("    " + (", ".join(map(str, home_dates[i])) if home_dates[i] else "None"))
    # (b)
    print("(b) # times HOSTED each opponent:")
    if home_vs_count[i]:
        for j in sorted(home_vs_count[i]):
            print(f"    vs {j} at HOME: {home_vs_count[i][j]}")
    else:
        print("    None")
    # (c)
    print("(c) # times VISITED each opponent:")
    if away_vs_count[i]:
        for j in sorted(away_vs_count[i]):
            print(f"    at {j} (AWAY): {away_vs_count[i][j]}")
    else:
        print("    None")
    # (d)
    print("(d) Away dates:")
    print("    " + (", ".join(map(str, away_dates[i])) if away_dates[i] else "None"))

print("===== Q1 Summaries =====")
for team in teams:
    print_team_summary(team)
# Out:
# ===== Q1 Summaries =====
#
# TEAM: Atlanta Hawks
# (a) Home dates:
#     2025-11-03, 2025-11-07, 2025-11-15, 2025-11-17, 2025-11-19, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Boston Celtics at HOME: 1
#     vs Chicago Bulls at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Phoenix Suns at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Brooklyn Nets (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-05, 2025-11-11, 2025-11-13, 2025-11-21, 2025-12-01
#
# TEAM: Boston Celtics
# (a) Home dates:
#     2025-11-01, 2025-11-07, 2025-11-13, 2025-11-19, 2025-11-23, 2025-11-28
# (b) # times HOSTED each opponent:
#     vs Dallas Mavericks at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
#     vs Phoenix Suns at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Brooklyn Nets (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-05, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-21, 2025-11-27, 2025-11-29, 2025-12-01, 2025-12-25
#
# TEAM: Brooklyn Nets
# (a) Home dates:
#     2025-11-01, 2025-11-05, 2025-11-11, 2025-11-13, 2025-11-21, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Boston Celtics at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
# (c) # times VISITED each opponent:
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Phoenix Suns (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-07, 2025-11-15, 2025-11-17, 2025-11-19, 2025-11-23, 2025-11-27, 2025-11-28, 2025-12-25
#
# TEAM: Chicago Bulls
# (a) Home dates:
#     2025-11-01, 2025-11-03, 2025-11-13, 2025-11-21, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
#     at Phoenix Suns (AWAY): 1
# (d) Away dates:
#     2025-11-05, 2025-11-07, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-19, 2025-12-25
#
# TEAM: Cleveland Cavaliers
# (a) Home dates:
#     2025-11-03, 2025-11-07, 2025-11-17, 2025-11-19, 2025-11-21, 2025-11-23, 2025-11-28, 2025-11-29, 2025-12-01, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Chicago Bulls at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Dallas Mavericks (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
#     at Phoenix Suns (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-05, 2025-11-11, 2025-11-13, 2025-11-15, 2025-11-27
#
# TEAM: Dallas Mavericks
# (a) Home dates:
#     2025-11-03, 2025-11-07, 2025-11-15, 2025-11-17, 2025-11-19, 2025-11-23, 2025-11-27, 2025-11-28, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Chicago Bulls at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Boston Celtics (AWAY): 1
#     at Brooklyn Nets (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Phoenix Suns (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-05, 2025-11-11, 2025-11-13, 2025-11-21, 2025-11-29, 2025-12-01
#
# TEAM: Denver Nuggets
# (a) Home dates:
#     2025-11-05, 2025-11-07, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-19, 2025-11-21, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
# (c) # times VISITED each opponent:
#     at Brooklyn Nets (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Phoenix Suns (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-03, 2025-11-13, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
#
# TEAM: Golden State Warriors
# (a) Home dates:
#     2025-11-03, 2025-11-05, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-27, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Boston Celtics at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Boston Celtics (AWAY): 1
#     at Brooklyn Nets (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Phoenix Suns (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-07, 2025-11-13, 2025-11-19, 2025-11-21, 2025-11-23, 2025-11-28, 2025-11-29, 2025-12-01
#
# TEAM: Houston Rockets
# (a) Home dates:
#     2025-11-03, 2025-11-11, 2025-11-13, 2025-11-15, 2025-11-19, 2025-11-21, 2025-11-23, 2025-11-27, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
#     vs Phoenix Suns at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-05, 2025-11-07, 2025-11-17, 2025-11-28, 2025-11-29, 2025-12-01
#
# TEAM: Los Angeles Lakers
# (a) Home dates:
#     2025-11-03, 2025-11-05, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-19, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Phoenix Suns at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-07, 2025-11-13, 2025-11-21, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
#
# TEAM: Miami Heat
# (a) Home dates:
#     2025-11-01, 2025-11-05, 2025-11-13, 2025-11-17, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Chicago Bulls at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
#     vs Phoenix Suns at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Boston Celtics (AWAY): 1
#     at Brooklyn Nets (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-07, 2025-11-11, 2025-11-15, 2025-11-19, 2025-11-21, 2025-11-23, 2025-12-25
#
# TEAM: Milwaukee Bucks
# (a) Home dates:
#     2025-11-01, 2025-11-07, 2025-11-13, 2025-11-21, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Brooklyn Nets at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
#     vs Phoenix Suns at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Boston Celtics (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-05, 2025-11-11, 2025-11-15, 2025-11-17, 2025-11-19, 2025-12-25
#
# TEAM: New York Knicks
# (a) Home dates:
#     2025-11-01, 2025-11-05, 2025-11-11, 2025-11-13, 2025-11-15, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Chicago Bulls at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
#     at Phoenix Suns (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-07, 2025-11-17, 2025-11-19, 2025-11-21, 2025-11-23, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-25
#
# TEAM: Philadelphia 76ers
# (a) Home dates:
#     2025-11-01, 2025-11-05, 2025-11-07, 2025-11-11, 2025-11-21, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Atlanta Hawks at HOME: 1
#     vs Chicago Bulls at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Los Angeles Lakers at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Phoenix Suns at HOME: 1
#     vs Toronto Raptors at HOME: 1
# (c) # times VISITED each opponent:
#     at Boston Celtics (AWAY): 1
#     at Brooklyn Nets (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Denver Nuggets (AWAY): 1
#     at Golden State Warriors (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Phoenix Suns (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-13, 2025-11-15, 2025-11-17, 2025-11-19, 2025-11-23, 2025-11-27, 2025-11-28, 2025-12-25
#
# TEAM: Phoenix Suns
# (a) Home dates:
#     2025-11-03, 2025-11-11, 2025-11-13, 2025-11-15, 2025-11-19, 2025-11-21, 2025-11-23, 2025-12-25
# (b) # times HOSTED each opponent:
#     vs Brooklyn Nets at HOME: 1
#     vs Chicago Bulls at HOME: 1
#     vs Cleveland Cavaliers at HOME: 1
#     vs Dallas Mavericks at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs New York Knicks at HOME: 1
#     vs Philadelphia 76ers at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Boston Celtics (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at Miami Heat (AWAY): 1
#     at Milwaukee Bucks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
#     at Toronto Raptors (AWAY): 1
# (d) Away dates:
#     2025-11-01, 2025-11-05, 2025-11-07, 2025-11-17, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
#
# TEAM: Toronto Raptors
# (a) Home dates:
#     2025-11-01, 2025-11-05, 2025-11-07, 2025-11-17, 2025-11-27, 2025-11-28, 2025-11-29, 2025-12-01
# (b) # times HOSTED each opponent:
#     vs Boston Celtics at HOME: 1
#     vs Brooklyn Nets at HOME: 1
#     vs Denver Nuggets at HOME: 1
#     vs Golden State Warriors at HOME: 1
#     vs Houston Rockets at HOME: 1
#     vs Miami Heat at HOME: 1
#     vs Milwaukee Bucks at HOME: 1
#     vs Phoenix Suns at HOME: 1
# (c) # times VISITED each opponent:
#     at Atlanta Hawks (AWAY): 1
#     at Chicago Bulls (AWAY): 1
#     at Cleveland Cavaliers (AWAY): 1
#     at Dallas Mavericks (AWAY): 1
#     at Houston Rockets (AWAY): 1
#     at Los Angeles Lakers (AWAY): 1
#     at New York Knicks (AWAY): 1
#     at Philadelphia 76ers (AWAY): 1
# (d) Away dates:
#     2025-11-03, 2025-11-11, 2025-11-13, 2025-11-15, 2025-11-19, 2025-11-21, 2025-11-23, 2025-12-25

# %%
teams
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Los Angeles Lakers',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'New York Knicks',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Toronto Raptors']

# %% [markdown]
# Sets
#
# T = set of all teams
# (e.g., from Python: teams = sorted(set(df["Home"]).union(set(df["Visitor"]))))
#
# D = set of all dates
# (e.g., from Python: dates = sorted(df["Date"].unique()))
#
# Indices:
#
# i in T : team index (home role)
#
# j in T : team index (away role)
#
# d in D : date index
#
# i != j
#
# H_date[i,d] = 1 if team i plays at home on date d, 0 otherwise.
# (Derived from home_dates[i].)
#
# A_date[i,d] = 1 if team i plays away on date d, 0 otherwise.
# (Derived from away_dates[i].)
#
# H_pair[i,j] = total number of times team i plays at home vs team j.
# (Derived from home_vs_counts[i][j].)
#
# A_pair[i,j] = total number of times team i plays away at team j’s home.
# (Derived from away_vs_counts[i][j].)
#
# x[i,j,d] in {0, 1}
#
# Interpretation:
#
# x[i,j,d] = 1 if on date d, team i plays at home vs team j (away).
#
# x[i,j,d] = 0 otherwise.

# %%
# Dates from the dataframe
dates = sorted(df["date"].unique())

# %%
# !pip install gurobipy
# Out:
# Collecting gurobipy
#   Downloading gurobipy-13.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (16 kB)
# Downloading gurobipy-13.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-13.0.0

# %%
from google.colab import userdata

# Create an environment with your WLS license
params = {
"WLSACCESSID": "206b3829-27fe-4e85-b2b5-40f61b2d7366",
"WLSSECRET": "f86b22c6-80f1-49ab-a97a-a3ad7bf5149a",
"LICENSEID": 2709572
}

env = Env(params=params)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2709572
# Academic license 2709572 - for non-commercial use only - registered to mg___@columbia.edu

# %% [markdown]
# ## Part 2

# %%
# --------------------------------------------------
# Time zone encoding (differences)
# Eastern = 0, Central = 1, Mountain = 2, Pacific = 3
# --------------------------------------------------
tz_team = {
    'Atlanta Hawks': 0,
    'Boston Celtics': 0,
    'Brooklyn Nets': 0,
    'New York Knicks': 0,
    'Philadelphia 76ers': 0,
    'Toronto Raptors': 0,
    'Miami Heat': 0,
    'Cleveland Cavaliers': 0,
    'Chicago Bulls': 1,
    'Milwaukee Bucks': 1,
    'Dallas Mavericks': 1,
    'Houston Rockets': 1,
    'Denver Nuggets': 2,
    'Phoenix Suns': 2,
    'Golden State Warriors': 3,
    'Los Angeles Lakers': 3,
}

H_date = {(i, d): 0 for i in teams for d in dates}
A_date = {(i, d): 0 for i in teams for d in dates}

for _, row in df.iterrows():
    home = row["home_team"]
    away = row["away_team"]
    d = row["date"]
    if home in teams:
        H_date[(home, d)] = 1
    if away in teams:
        A_date[(away, d)] = 1

H_pair = {(i, j): 0 for i in teams for j in teams if i != j}
A_pair = {(i, j): 0 for i in teams for j in teams if i != j}

for _, row in df.iterrows():
    home = row["home_team"]
    away = row["away_team"]
    if home in teams and away in teams and home != away:
        H_pair[(home, away)] += 1
        A_pair[(away, home)] += 1

# For each team, list of dates when they play (home or away), sorted
game_dates = {}
for i in teams:
    ds = [d for d in dates if H_date[(i, d)] == 1 or A_date[(i, d)] == 1]
    game_dates[i] = sorted(ds)

# Model and decision Variable

m = gp.Model("schedule_with_triple_travel_hard", env=env)

# x[i,j,d] = 1 if on date d, team i is home vs team j (away)
x = m.addVars(
    [(i, j, d) for i in teams for j in teams for d in dates if i != j],
    vtype=GRB.BINARY,
    name="x"
)

# Constraints

# (e) Home schedule fixed: sum_j x[i,j,d] = H_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[i, j, d] for j in teams if i != j) == H_date[(i, d)],
            name=f"home_schedule_{i}_{d}"
        )

# (f) Away schedule fixed: sum_j x[j,i,d] = A_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[j, i, d] for j in teams if i != j) == A_date[(i, d)],
            name=f"away_schedule_{i}_{d}"
        )

# (g) Home pair counts: sum_d x[i,j,d] = H_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[i, j, d] for d in dates) == H_pair[(i, j)],
            name=f"home_pair_{i}_vs_{j}"
        )

# (h) Away pair counts: sum_d x[j,i,d] = A_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[j, i, d] for d in dates) == A_pair[(i, j)],
            name=f"away_pair_{i}_at_{j}"
        )


# Objective:

m.setObjective(0.0, GRB.MINIMIZE)

# Solve

m.optimize()

# Print schedule

if m.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
    print("A feasible schedule satisfying the hard 3-game constraint was found.")

    # --- Schedule output ---
    schedule_rows = []
    for d in dates:
        for i in teams:
            for j in teams:
                if i == j:
                    continue
                key = (i, j, d)
                if key in x and x[key].X > 0.5:
                    schedule_rows.append({
                        "date": d,
                        "home_team": i,
                        "away_team": j,
                        "home_tz": tz_team[i],
                        "away_tz": tz_team[j]
                    })

    schedule_df = pd.DataFrame(schedule_rows).sort_values(by=["date", "home_team"])
    print("\n=== Schedule (home/away per date) ===")
    print(schedule_df)

else:
    print("No feasible schedule found with the hard 3-game constraint. Model status:", m.Status)
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7B12, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Academic license 2709572 - for non-commercial use only - registered to mg___@columbia.edu
# Optimize a model with 992 rows, 3840 columns and 15360 nonzeros (Min)
# Model fingerprint: 0xb3f76766
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 3840 integer (3840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 684 rows and 3398 columns
# Presolve time: 0.01s
# Presolved: 308 rows, 442 columns, 1386 nonzeros
# Variable types: 0 continuous, 442 integer (442 binary)
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# A feasible schedule satisfying the hard 3-game constraint was found.
#
# === Schedule (home/away per date) ===
#            date              home_team           away_team  home_tz  away_tz
# 0    2025-11-01         Boston Celtics        Phoenix Suns        0        2
# 1    2025-11-01          Brooklyn Nets      Denver Nuggets        0        2
# 2    2025-11-01          Chicago Bulls       Atlanta Hawks        1        0
# 3    2025-11-01             Miami Heat     Houston Rockets        0        1
# 4    2025-11-01        Milwaukee Bucks    Dallas Mavericks        1        1
# ..          ...                    ...                 ...      ...      ...
# 123  2025-12-25         Denver Nuggets          Miami Heat        2        0
# 124  2025-12-25  Golden State Warriors     New York Knicks        3        0
# 125  2025-12-25        Houston Rockets     Toronto Raptors        1        0
# 126  2025-12-25     Los Angeles Lakers       Brooklyn Nets        3        0
# 127  2025-12-25           Phoenix Suns  Philadelphia 76ers        2        0
#
# [128 rows x 5 columns]

# %% [markdown]
# ### Check if the produced schedule from part 2 is different from the original schedule

# %%
orig_simple = df[['date', 'home_team', 'away_team']].copy()
orig_simple['date'] = pd.to_datetime(orig_simple['date']).dt.date

# %%
new_simple = schedule_df[['date', 'home_team', 'away_team']].copy()

# %%
orig_sorted = orig_simple.sort_values(['date', 'home_team', 'away_team']).reset_index(drop=True)
new_sorted = new_simple.sort_values(['date', 'home_team', 'away_team']).reset_index(drop=True)

# %%
orig_sorted.equals(new_sorted)
# Out:
# False

# %%
orig_sorted
# Out:
#            date              home_team              away_team
# 0    2025-11-01         Boston Celtics  Golden State Warriors
# 1    2025-11-01          Brooklyn Nets         Denver Nuggets
# 2    2025-11-01          Chicago Bulls          Atlanta Hawks
# 3    2025-11-01             Miami Heat       Dallas Mavericks
# 4    2025-11-01        Milwaukee Bucks    Cleveland Cavaliers
# ..          ...                    ...                    ...
# 123  2025-12-25         Denver Nuggets          Brooklyn Nets
# 124  2025-12-25  Golden State Warriors         Boston Celtics
# 125  2025-12-25        Houston Rockets        Toronto Raptors
# 126  2025-12-25     Los Angeles Lakers        New York Knicks
# 127  2025-12-25           Phoenix Suns     Philadelphia 76ers
#
# [128 rows x 3 columns]

# %%
new_sorted
# Out:
#            date              home_team           away_team
# 0    2025-11-01         Boston Celtics        Phoenix Suns
# 1    2025-11-01          Brooklyn Nets      Denver Nuggets
# 2    2025-11-01          Chicago Bulls       Atlanta Hawks
# 3    2025-11-01             Miami Heat     Houston Rockets
# 4    2025-11-01        Milwaukee Bucks    Dallas Mavericks
# ..          ...                    ...                 ...
# 123  2025-12-25         Denver Nuggets          Miami Heat
# 124  2025-12-25  Golden State Warriors     New York Knicks
# 125  2025-12-25        Houston Rockets     Toronto Raptors
# 126  2025-12-25     Los Angeles Lakers       Brooklyn Nets
# 127  2025-12-25           Phoenix Suns  Philadelphia 76ers
#
# [128 rows x 3 columns]

# %%
# Convert it to csv file
new_sorted.to_csv("new_schedule(part 2).csv", index=False)

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### Hard Constraint
#
# For this section, we will be implementing the additional constraint: no team
# should play three consecutive matches where the sum of the absolute values of the difference between the time zones of two consecutive matches is 4 or more; or conclude that no such schedule exists.

# %%
# Model and decision Variable

m = gp.Model("schedule_with_triple_travel_hard", env=env)

# x[i,j,d] = 1 if on date d, team i is home vs team j (away)
x = m.addVars(
    [(i, j, d) for i in teams for j in teams for d in dates if i != j],
    vtype=GRB.BINARY,
    name="x"
)

# Constraints

# (e) Home schedule fixed: sum_j x[i,j,d] = H_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[i, j, d] for j in teams if i != j) == H_date[(i, d)],
            name=f"home_schedule_{i}_{d}"
        )

# (f) Away schedule fixed: sum_j x[j,i,d] = A_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[j, i, d] for j in teams if i != j) == A_date[(i, d)],
            name=f"away_schedule_{i}_{d}"
        )

# (g) Home pair counts: sum_d x[i,j,d] = H_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[i, j, d] for d in dates) == H_pair[(i, j)],
            name=f"home_pair_{i}_vs_{j}"
        )

# (h) Away pair counts: sum_d x[j,i,d] = A_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[j, i, d] for d in dates) == A_pair[(i, j)],
            name=f"away_pair_{i}_at_{j}"
        )

# # --------------------------------------------------
# # 3) Hard 3-game time-zone constraint (part 3)
# #     For every team i and every triple of consecutive games:
# #     |tz2 - tz1| + |tz3 - tz2| <= 3
# # --------------------------------------------------

# # game_dates[i] already holds the sorted dates when team i plays (home or away)

for i in teams:
    games = game_dates[i]
    if len(games) < 3:
        continue  # no triple for this team

    for k in range(len(games) - 2):
        d1 = games[k]
        d2 = games[k + 1]
        d3 = games[k + 2]

        # Time zone of team i's arena for each of the three games:
        #   - if i is home: tz_team[i]
        #   - if i is away at j: tz_team[j]
        tz_d1 = (
            tz_team[i] * gp.quicksum(x[i, j, d1] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d1] for j in teams if i != j)
        )
        tz_d2 = (
            tz_team[i] * gp.quicksum(x[i, j, d2] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d2] for j in teams if i != j)
        )
        tz_d3 = (
            tz_team[i] * gp.quicksum(x[i, j, d3] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d3] for j in teams if i != j)
        )

        # Continuous vars for the absolute jumps
        diff1 = m.addVar(lb=0.0, vtype=GRB.CONTINUOUS,
                         name=f"diff1_{i}_{k}")
        diff2 = m.addVar(lb=0.0, vtype=GRB.CONTINUOUS,
                         name=f"diff2_{i}_{k}")

        # diff1 >= |tz_d2 - tz_d1|
        m.addConstr(diff1 >= tz_d2 - tz_d1, name=f"diff1_pos_{i}_{k}")
        m.addConstr(diff1 >= -(tz_d2 - tz_d1), name=f"diff1_neg_{i}_{k}")

        # diff2 >= |tz_d3 - tz_d2|
        m.addConstr(diff2 >= tz_d3 - tz_d2, name=f"diff2_pos_{i}_{k}")
        m.addConstr(diff2 >= -(tz_d3 - tz_d2), name=f"diff2_neg_{i}_{k}")

        # Hard constraint: no triple with sum of jumps >= 4
        m.addConstr(diff1 + diff2 <= 3, name=f"triple_hard_{i}_{k}")


# Objective:

m.setObjective(0.0, GRB.MINIMIZE)

# Solve

m.optimize()

# Print schedule

if m.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
    print("A feasible schedule satisfying the hard 3-game constraint was found.")

    # --- Schedule output ---
    schedule_rows = []
    for d in dates:
        for i in teams:
            for j in teams:
                if i == j:
                    continue
                key = (i, j, d)
                if key in x and x[key].X > 0.5:
                    schedule_rows.append({
                        "date": d,
                        "home_team": i,
                        "away_team": j,
                        "home_tz": tz_team[i],
                        "away_tz": tz_team[j]
                    })

    schedule_df = pd.DataFrame(schedule_rows).sort_values(by=["date", "home_team"])
    print("\n=== Schedule (home/away per date) ===")
    print(schedule_df)

else:
    print("No feasible schedule found with the hard 3-game constraint. Model status:", m.Status)
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7B12, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Academic license 2709572 - for non-commercial use only - registered to mg___@columbia.edu
# Optimize a model with 2112 rows, 4288 columns and 43584 nonzeros (Min)
# Model fingerprint: 0x4bdc49f2
# Model has 0 linear objective coefficients
# Variable types: 448 continuous, 3840 integer (3840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 1014 rows and 3489 columns
# Presolve time: 0.01s
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# No feasible schedule found with the hard 3-game constraint. Model status: 3

# %% [markdown]
# ### Soft Penalty
# We aren't able to get a feasible solution for implementing the thrid constraint, so instead, we tried to formulate it as a soft penalty to discourage as many violations of the 3rd rule as possible.

# %%
# --------------------------------------------------
# 1. Define model and decision variables
# --------------------------------------------------
m = gp.Model("schedule_with_triple_travel", env=env)

# x[i,j,d] = 1 if on date d, team i is home vs team j (away)
x = m.addVars(
    [(i, j, d) for i in teams for j in teams for d in dates if i != j],
    vtype=GRB.BINARY,
    name="x"
)

# --------------------------------------------------
# 2. Core schedule constraints (e)–(h)
# --------------------------------------------------

# (e) Home schedule fixed: sum_j x[i,j,d] = H_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[i, j, d] for j in teams if i != j) == H_date[(i, d)],
            name=f"home_schedule_{i}_{d}"
        )

# (f) Away schedule fixed: sum_j x[j,i,d] = A_date[i,d]
for i in teams:
    for d in dates:
        m.addConstr(
            gp.quicksum(x[j, i, d] for j in teams if i != j) == A_date[(i, d)],
            name=f"away_schedule_{i}_{d}"
        )

# (g) Home pair counts: sum_d x[i,j,d] = H_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[i, j, d] for d in dates) == H_pair[(i, j)],
            name=f"home_pair_{i}_vs_{j}"
        )

# (h) Away pair counts: sum_d x[j,i,d] = A_pair[i,j]
for i in teams:
    for j in teams:
        if i == j:
            continue
        m.addConstr(
            gp.quicksum(x[j, i, d] for d in dates) == A_pair[(i, j)],
            name=f"away_pair_{i}_at_{j}"
        )

# --------------------------------------------------
# 3. Soft 3-game penalty ONLY (no 2-game constraint)
# --------------------------------------------------

viol = {}
diff1_vars = {}
diff2_vars = {}
M = 3 # max possible sum of two jumps (3 + 3)

for i in teams:
    games = game_dates[i]
    if len(games) < 3:
        continue

    for k in range(len(games) - 2):
        d1 = games[k]
        d2 = games[k + 1]
        d3 = games[k + 2]

        # Binary: 1 if this triple is "bad" (sum of jumps can exceed 3)
        viol[i, k] = m.addVar(vtype=GRB.BINARY, name=f"viol_{i}_{k}")

        diff1 = m.addVar(lb=0.0, vtype=GRB.CONTINUOUS, name=f"diff1_{i}_{k}")
        diff2 = m.addVar(lb=0.0, vtype=GRB.CONTINUOUS, name=f"diff2_{i}_{k}")
        diff1_vars[(i, k)] = diff1
        diff2_vars[(i, k)] = diff2

        tz_d1 = (
            tz_team[i] * gp.quicksum(x[i, j, d1] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d1] for j in teams if i != j)
        )
        tz_d2 = (
            tz_team[i] * gp.quicksum(x[i, j, d2] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d2] for j in teams if i != j)
        )
        tz_d3 = (
            tz_team[i] * gp.quicksum(x[i, j, d3] for j in teams if i != j) +
            gp.quicksum(tz_team[j] * x[j, i, d3] for j in teams if i != j)
        )

        # diff1 >= |tz_d2 - tz_d1|
        m.addConstr(diff1 >= tz_d2 - tz_d1)
        m.addConstr(diff1 >= -(tz_d2 - tz_d1))

        # diff2 >= |tz_d3 - tz_d2|
        m.addConstr(diff2 >= tz_d3 - tz_d2)
        m.addConstr(diff2 >= -(tz_d3 - tz_d2))

        # Soft 3-game constraint:
        # If viol[i,k] = 0 -> diff1 + diff2 <= 3 (good triple)
        # If viol[i,k] = 1 -> diff1 + diff2 <= 3 + M (allowed but penalized)
        m.addConstr(diff1 + diff2 <= 3 + M * viol[i, k],
                    name=f"triple_travel_soft_{i}_{k}")

# --------------------------------------------------
# 5. Objective: minimize number of "bad triples"
# --------------------------------------------------

if viol:
    m.setObjective(gp.quicksum(viol[i, k] for (i, k) in viol), GRB.MINIMIZE)
else:
    m.setObjective(0.0, GRB.MINIMIZE)

# --------------------------------------------------
# 6. Solve
# --------------------------------------------------

m.optimize()

# --------------------------------------------------
# 7. Print schedule and triple violations
# --------------------------------------------------

if m.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL):
    print("A feasible schedule was found.")

    # --- Schedule output ---
    schedule_rows = []
    for d in dates:
        for i in teams:
            for j in teams:
                if i == j:
                    continue
                key = (i, j, d)
                if key in x and x[key].X > 0.5:
                    schedule_rows.append({
                        "date": d,
                        "home_team": i,
                        "away_team": j,
                        "home_tz": tz_team[i],
                        "away_tz": tz_team[j]
                    })
    schedule_df = pd.DataFrame(schedule_rows).sort_values(by=["date", "home_team"])
    print("\n=== Schedule (home/away per date) ===")
    print(schedule_df)

    # --- Triple violations report ---
    violating_rows = []

    for (team, k), v in viol.items():
        if v.X <= 0.5:
            continue  # only triples with viol=1

        games = game_dates[team]
        d1 = games[k]
        d2 = games[k + 1]
        d3 = games[k + 2]

        # Helper: find arena team and tz for this team on a given date
        def get_arena_team_and_tz(team_i, date_d):
            home_arena_team = None
            away_arena_team = None

            # If team_i is home
            for opp in teams:
                if opp == team_i:
                    continue
                if (team_i, opp, date_d) in x and x[team_i, opp, date_d].X > 0.5:
                    home_arena_team = team_i
                    break

            # If team_i is away
            if home_arena_team is None:
                for opp in teams:
                    if opp == team_i:
                        continue
                    if (opp, team_i, date_d) in x and x[opp, team_i, date_d].X > 0.5:
                        away_arena_team = opp
                        break

            if home_arena_team is not None:
                arena_team = home_arena_team
            elif away_arena_team is not None:
                arena_team = away_arena_team
            else:
                return None, None

            return arena_team, tz_team[arena_team]

        arena1, tz1 = get_arena_team_and_tz(team, d1)
        arena2, tz2 = get_arena_team_and_tz(team, d2)
        arena3, tz3 = get_arena_team_and_tz(team, d3)

        if arena1 is None or arena2 is None or arena3 is None:
            continue

        diff12 = abs(tz2 - tz1)
        diff23 = abs(tz3 - tz2)
        total_diff = diff12 + diff23

        violating_rows.append({
            "team": team,
            "triple_index_for_team": k,
            "date_1": d1,
            "arena_1": arena1,
            "tz_1": tz1,
            "date_2": d2,
            "arena_2": arena2,
            "tz_2": tz2,
            "date_3": d3,
            "arena_3": arena3,
            "tz_3": tz3,
            "jump_1_2": diff12,
            "jump_2_3": diff23,
            "sum_jumps": total_diff
        })

    viol_df = pd.DataFrame(violating_rows).sort_values(by=["team", "date_1"])
    print("\nNumber of violating triples found in solution:", len(viol_df))
    if len(viol_df) > 0:
        print("\n=== Violating triples ===")
        print(viol_df)

else:
    print("No feasible schedule found. Model status:", m.Status)
# Out:
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7B12, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Academic license 2709572 - for non-commercial use only - registered to mg___@columbia.edu
# Optimize a model with 2112 rows, 4512 columns and 43808 nonzeros (Min)
# Model fingerprint: 0xa522a451
# Model has 224 linear objective coefficients
# Variable types: 448 continuous, 4064 integer (4064 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Presolve removed 1621 rows and 3944 columns
# Presolve time: 0.03s
# Presolved: 491 rows, 568 columns, 2404 nonzeros
# Variable types: 38 continuous, 530 integer (508 binary)
# Found heuristic solution: objective 33.0000000
# Found heuristic solution: objective 32.0000000
# Found heuristic solution: objective 31.0000000
# Found heuristic solution: objective 30.0000000
#
# Root relaxation: objective 9.194444e+00, 691 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.19444    0  236   30.00000    9.19444  69.4%     -    0s
# H    0     0                      22.0000000    9.19444  58.2%     -    0s
# H    0     0                      21.0000000    9.19444  56.2%     -    0s
#      0     0   12.21053    0  289   21.00000   12.21053  41.9%     -    0s
#      0     0   12.23529    0  291   21.00000   12.23529  41.7%     -    0s
#      0     0   12.85106    0  297   21.00000   12.85106  38.8%     -    0s
#      0     0   12.88000    0  284   21.00000   12.88000  38.7%     -    0s
#      0     0   12.88000    0  281   21.00000   12.88000  38.7%     -    0s
#      0     0   13.38984    0  302   21.00000   13.38984  36.2%     -    0s
#      0     0   13.49530    0  299   21.00000   13.49530  35.7%     -    0s
#      0     0   13.53390    0  298   21.00000   13.53390  35.6%     -    0s
#      0     0   13.53390    0  300   21.00000   13.53390  35.6%     -    0s
#      0     0   13.55000    0  301   21.00000   13.55000  35.5%     -    0s
# H    0     0                      20.0000000   13.56667  32.2%     -    0s
#      0     0   13.60227    0  306   20.00000   13.60227  32.0%     -    0s
#      0     0   13.62500    0  261   20.00000   13.62500  31.9%     -    0s
#      0     0   13.70930    0  297   20.00000   13.70930  31.5%     -    0s
# H    0     0                      18.0000000   13.71875  23.8%     -    0s
#      0     0   13.71875    0  291   18.00000   13.71875  23.8%     -    0s
#      0     0   13.71875    0  297   18.00000   13.71875  23.8%     -    0s
#      0     0   13.71875    0  300   18.00000   13.71875  23.8%     -    0s
#      0     0   13.72727    0  300   18.00000   13.72727  23.7%     -    0s
#      0     0   13.72727    0  299   18.00000   13.72727  23.7%     -    0s
#      0     0   13.72727    0  299   18.00000   13.72727  23.7%     -    0s
#      0     0   13.72727    0  287   18.00000   13.72727  23.7%     -    0s
#      0     2   13.75000    0  287   18.00000   13.75000  23.6%     -    0s
# *   15    13               9      17.0000000   14.14286  16.8%  86.1    0s
# *   30    10               9      16.0000000   14.14286  11.6%  67.2    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 15
#   Clique: 4
#   MIR: 5
#   GUB cover: 10
#   Zero half: 6
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 56 nodes (4981 simplex iterations) in 0.52 seconds (0.37 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 10: 16 17 18 ... 33
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# A feasible schedule was found.
#
# === Schedule (home/away per date) ===
#            date              home_team              away_team  home_tz  \
# 0    2025-11-01         Boston Celtics           Phoenix Suns        0
# 1    2025-11-01          Brooklyn Nets         Denver Nuggets        0
# 2    2025-11-01          Chicago Bulls  Golden State Warriors        1
# 3    2025-11-01             Miami Heat     Los Angeles Lakers        0
# 4    2025-11-01        Milwaukee Bucks    Cleveland Cavaliers        1
# ..          ...                    ...                    ...      ...
# 123  2025-12-25         Denver Nuggets             Miami Heat        2
# 124  2025-12-25  Golden State Warriors     Philadelphia 76ers        3
# 125  2025-12-25        Houston Rockets         Boston Celtics        1
# 126  2025-12-25     Los Angeles Lakers          Brooklyn Nets        3
# 127  2025-12-25           Phoenix Suns        New York Knicks        2
#
#      away_tz
# 0          2
# 1          2
# 2          3
# 3          3
# 4          0
# ..       ...
# 123        0
# 124        0
# 125        0
# 126        0
# 127        0
#
# [128 rows x 5 columns]
#
# Number of violating triples found in solution: 16
#
# === Violating triples ===
#                      team  triple_index_for_team      date_1  \
# 0          Boston Celtics                      1  2025-11-03
# 1           Brooklyn Nets                      0  2025-11-01
# 2           Brooklyn Nets                      7  2025-11-17
# 3     Cleveland Cavaliers                      3  2025-11-07
# 4     Cleveland Cavaliers                      5  2025-11-13
# 5   Golden State Warriors                      2  2025-11-05
# 6   Golden State Warriors                      3  2025-11-07
# 7   Golden State Warriors                      4  2025-11-11
# 8   Golden State Warriors                     10  2025-11-23
# 9         Houston Rockets                      1  2025-11-03
# 10     Los Angeles Lakers                      4  2025-11-11
# 11        Milwaukee Bucks                      3  2025-11-07
# 12        New York Knicks                      0  2025-11-01
# 13        New York Knicks                      6  2025-11-15
# 14           Phoenix Suns                      6  2025-11-15
# 15        Toronto Raptors                      0  2025-11-01
#
#                   arena_1  tz_1      date_2                arena_2  tz_2  \
# 0           Atlanta Hawks     0  2025-11-05         Denver Nuggets     2
# 1           Brooklyn Nets     0  2025-11-03           Phoenix Suns     2
# 2         Toronto Raptors     0  2025-11-19         Denver Nuggets     2
# 3     Cleveland Cavaliers     0  2025-11-11     Los Angeles Lakers     3
# 4            Phoenix Suns     2  2025-11-15  Golden State Warriors     3
# 5   Golden State Warriors     3  2025-11-07         Boston Celtics     0
# 6          Boston Celtics     0  2025-11-11  Golden State Warriors     3
# 7   Golden State Warriors     3  2025-11-13             Miami Heat     0
# 8        Dallas Mavericks     1  2025-11-27  Golden State Warriors     3
# 9         Houston Rockets     1  2025-11-05  Golden State Warriors     3
# 10     Los Angeles Lakers     3  2025-11-13          Chicago Bulls     1
# 11        Milwaukee Bucks     1  2025-11-11  Golden State Warriors     3
# 12        New York Knicks     0  2025-11-03  Golden State Warriors     3
# 13        New York Knicks     0  2025-11-17     Los Angeles Lakers     3
# 14           Phoenix Suns     2  2025-11-17          Atlanta Hawks     0
# 15        Toronto Raptors     0  2025-11-03     Los Angeles Lakers     3
#
#         date_3                arena_3  tz_3  jump_1_2  jump_2_3  sum_jumps
# 0   2025-11-07         Boston Celtics     0         2         2          4
# 1   2025-11-05          Brooklyn Nets     0         2         2          4
# 2   2025-11-21          Brooklyn Nets     0         2         2          4
# 3   2025-11-13           Phoenix Suns     2         3         1          4
# 4   2025-11-17    Cleveland Cavaliers     0         1         3          4
# 5   2025-11-11  Golden State Warriors     3         3         3          6
# 6   2025-11-13             Miami Heat     0         3         3          6
# 7   2025-11-15  Golden State Warriors     3         3         3          6
# 8   2025-11-28          Atlanta Hawks     0         2         3          5
# 9   2025-11-07       Dallas Mavericks     1         2         2          4
# 10  2025-11-15     Los Angeles Lakers     3         2         2          4
# 11  2025-11-13        Milwaukee Bucks     1         2         2          4
# 12  2025-11-05        New York Knicks     0         3         3          6
# 13  2025-11-19        Houston Rockets     1         3         2          5
# 14  2025-11-19           Phoenix Suns     2         2         2          4
# 15  2025-11-05        Toronto Raptors     0         3         3          6

# %%
schedule_df
# Out:
#            date              home_team              away_team  home_tz  \
# 0    2025-11-01         Boston Celtics           Phoenix Suns        0
# 1    2025-11-01          Brooklyn Nets         Denver Nuggets        0
# 2    2025-11-01          Chicago Bulls  Golden State Warriors        1
# 3    2025-11-01             Miami Heat     Los Angeles Lakers        0
# 4    2025-11-01        Milwaukee Bucks    Cleveland Cavaliers        1
# ..          ...                    ...                    ...      ...
# 123  2025-12-25         Denver Nuggets             Miami Heat        2
# 124  2025-12-25  Golden State Warriors     Philadelphia 76ers        3
# 125  2025-12-25        Houston Rockets         Boston Celtics        1
# 126  2025-12-25     Los Angeles Lakers          Brooklyn Nets        3
# 127  2025-12-25           Phoenix Suns        New York Knicks        2
#
#      away_tz
# 0          2
# 1          2
# 2          3
# 3          3
# 4          0
# ..       ...
# 123        0
# 124        0
# 125        0
# 126        0
# 127        0
#
# [128 rows x 5 columns]

# %%
# --- Schedule output ---
schedule_rows = []
for d in dates:
    for i in teams:
        for j in teams:
            if i == j:
                continue
            key = (i, j, d)
            if key in x and x[key].X > 0.5:
                schedule_rows.append({
                    "date": d,
                    "home_team": i,
                    "away_team": j,
                    "home_tz": tz_team[i],
                    "away_tz": tz_team[j]
                })

schedule_df = pd.DataFrame(schedule_rows).sort_values(by=["date", "home_team"])
print("\n=== Schedule (home/away per date) ===")
print(schedule_df)

# >>> ADD THIS <<<
# Save a clean schedule: date, home_team, away_team
schedule_df_simple = schedule_df[["date", "home_team", "away_team"]].copy()
schedule_df_simple.to_csv("optimized_schedule.csv", index=False)
print("\nSaved optimized schedule as optimized_schedule.csv")
# Out:
# === Schedule (home/away per date) ===
#            date              home_team              away_team  home_tz  \
# 0    2025-11-01         Boston Celtics           Phoenix Suns        0
# 1    2025-11-01          Brooklyn Nets         Denver Nuggets        0
# 2    2025-11-01          Chicago Bulls  Golden State Warriors        1
# 3    2025-11-01             Miami Heat     Los Angeles Lakers        0
# 4    2025-11-01        Milwaukee Bucks    Cleveland Cavaliers        1
# ..          ...                    ...                    ...      ...
# 123  2025-12-25         Denver Nuggets             Miami Heat        2
# 124  2025-12-25  Golden State Warriors     Philadelphia 76ers        3
# 125  2025-12-25        Houston Rockets         Boston Celtics        1
# 126  2025-12-25     Los Angeles Lakers          Brooklyn Nets        3
# 127  2025-12-25           Phoenix Suns        New York Knicks        2
#
#      away_tz
# 0          2
# 1          2
# 2          3
# 3          3
# 4          0
# ..       ...
# 123        0
# 124        0
# 125        0
# 126        0
# 127        0
#
# [128 rows x 5 columns]
#
# Saved optimized schedule as optimized_schedule.csv

# %%
# --- Build new compact schedule ---
df_reform = pd.DataFrame({
    "date": df["date"],
    "home_team": df["home_team"],
    "away_team": df["away_team"],
})

df_reform["home_tz"] = df_reform["home_team"].map(tz_team)
df_reform["away_tz"] = df_reform["away_team"].map(tz_team)

# Sort to match desired format order (optional)
df_reform= df_reform.sort_values(["date", "home_team"]).reset_index(drop=True)

df_reform.head()
# Out:
#          date        home_team              away_team  home_tz  away_tz
# 0  2025-11-01   Boston Celtics  Golden State Warriors        0        3
# 1  2025-11-01    Brooklyn Nets         Denver Nuggets        0        2
# 2  2025-11-01    Chicago Bulls          Atlanta Hawks        1        0
# 3  2025-11-01       Miami Heat       Dallas Mavericks        0        1
# 4  2025-11-01  Milwaukee Bucks    Cleveland Cavaliers        1        0

# %% [markdown]
# Check if the produced schedule is different from the original dataset

# %%
schedule_df.equals(df_reform)
# Out:
# False

# %% [markdown]
# Check how many violations the original schedule had

# %%
# Make sure dates are sorted correctly
df = df.sort_values("date").reset_index(drop=True)

# --------------------------------------------------
# 1. Time zone mapping and team list
# --------------------------------------------------

teams = list(tz_team.keys())

# --------------------------------------------------
# 2. Build per-team game sequences with arena time zones
# --------------------------------------------------

team_games = {t: [] for t in teams}

for _, row in df.iterrows():
    d = row["date"]
    home = row["home_team"]
    away = row["away_team"]

    # Home game
    if home in teams:
        team_games[home].append({
            "date": d,
            "arena_team": home,
            "tz": tz_team[home]
        })

    # Away game (played in *home* team's arena)
    if away in teams:
        team_games[away].append({
            "date": d,
            "arena_team": home,
            "tz": tz_team[home]
        })

# Sort each team's games by date
for t in teams:
    team_games[t] = sorted(team_games[t], key=lambda x: x["date"])

# --------------------------------------------------
# 3. Check 3-consecutive rule:
#    abs(tz2 - tz1) + abs(tz3 - tz2) >= 4
# --------------------------------------------------

three_violations = []

for team in teams:
    games = team_games[team]
    for k in range(len(games) - 2):
        g1 = games[k]
        g2 = games[k + 1]
        g3 = games[k + 2]

        diff12 = abs(g2["tz"] - g1["tz"])
        diff23 = abs(g3["tz"] - g2["tz"])
        total = diff12 + diff23

        if total >= 4:
            three_violations.append({
                "team": team,
                "triple_index_for_team": k,
                "date_1": g1["date"],
                "arena_1": g1["arena_team"],
                "tz_1": g1["tz"],
                "date_2": g2["date"],
                "arena_2": g2["arena_team"],
                "tz_2": g2["tz"],
                "date_3": g3["date"],
                "arena_3": g3["arena_team"],
                "tz_3": g3["tz"],
                "jump_1_2": diff12,
                "jump_2_3": diff23,
                "sum_jumps": total
            })

three_viol_df = pd.DataFrame(three_violations)

print("Number of 3-consecutive violations:", len(three_viol_df))

if not three_viol_df.empty:
    three_viol_df = three_viol_df.sort_values(by=["team", "date_1"]).reset_index(drop=True)
    display(three_viol_df)
else:
    print("No 3-consecutive violations found.")

# OPTIONAL: Save results
three_viol_df.to_csv("three_consecutive_violations.csv", index=False)
print("Saved as three_consecutive_violations.csv")
# Out:
# Number of 3-consecutive violations: 22
#                      team  triple_index_for_team      date_1  \
# 0          Boston Celtics                      0  2025-11-01
# 1           Brooklyn Nets                      6  2025-11-15
# 2     Cleveland Cavaliers                      3  2025-11-07
# 3     Cleveland Cavaliers                     10  2025-11-23
# 4          Denver Nuggets                      0  2025-11-01
# 5   Golden State Warriors                      2  2025-11-05
# 6   Golden State Warriors                      3  2025-11-07
# 7   Golden State Warriors                      4  2025-11-11
# 8   Golden State Warriors                     10  2025-11-23
# 9      Los Angeles Lakers                      2  2025-11-05
# 10     Los Angeles Lakers                      3  2025-11-07
# 11     Los Angeles Lakers                      4  2025-11-11
# 12             Miami Heat                      5  2025-11-13
# 13        Milwaukee Bucks                      3  2025-11-07
# 14        New York Knicks                      0  2025-11-01
# 15        New York Knicks                      6  2025-11-15
# 16     Philadelphia 76ers                      5  2025-11-13
# 17           Phoenix Suns                      1  2025-11-03
# 18           Phoenix Suns                      2  2025-11-05
# 19           Phoenix Suns                      6  2025-11-15
# 20        Toronto Raptors                      5  2025-11-13
# 21        Toronto Raptors                      6  2025-11-15
#
#                   arena_1  tz_1      date_2                arena_2  tz_2  \
# 0          Boston Celtics     0  2025-11-03     Los Angeles Lakers     3
# 1         New York Knicks     0  2025-11-17     Los Angeles Lakers     3
# 2     Cleveland Cavaliers     0  2025-11-11     Los Angeles Lakers     3
# 3     Cleveland Cavaliers     0  2025-11-27  Golden State Warriors     3
# 4           Brooklyn Nets     0  2025-11-03  Golden State Warriors     3
# 5   Golden State Warriors     3  2025-11-07          Atlanta Hawks     0
# 6           Atlanta Hawks     0  2025-11-11  Golden State Warriors     3
# 7   Golden State Warriors     3  2025-11-13             Miami Heat     0
# 8        Dallas Mavericks     1  2025-11-27  Golden State Warriors     3
# 9      Los Angeles Lakers     3  2025-11-07       Dallas Mavericks     1
# 10       Dallas Mavericks     1  2025-11-11     Los Angeles Lakers     3
# 11     Los Angeles Lakers     3  2025-11-13          Chicago Bulls     1
# 12             Miami Heat     0  2025-11-15         Denver Nuggets     2
# 13        Milwaukee Bucks     1  2025-11-11  Golden State Warriors     3
# 14        New York Knicks     0  2025-11-03           Phoenix Suns     2
# 15        New York Knicks     0  2025-11-17  Golden State Warriors     3
# 16          Brooklyn Nets     0  2025-11-15  Golden State Warriors     3
# 17           Phoenix Suns     2  2025-11-05     Los Angeles Lakers     3
# 18     Los Angeles Lakers     3  2025-11-07         Boston Celtics     0
# 19           Phoenix Suns     2  2025-11-17        Toronto Raptors     0
# 20        New York Knicks     0  2025-11-15     Los Angeles Lakers     3
# 21     Los Angeles Lakers     3  2025-11-17        Toronto Raptors     0
#
#         date_3                arena_3  tz_3  jump_1_2  jump_2_3  sum_jumps
# 0   2025-11-05         Denver Nuggets     2         3         1          4
# 1   2025-11-19           Phoenix Suns     2         3         1          4
# 2   2025-11-13           Phoenix Suns     2         3         1          4
# 3   2025-11-28    Cleveland Cavaliers     0         3         3          6
# 4   2025-11-05         Denver Nuggets     2         3         1          4
# 5   2025-11-11  Golden State Warriors     3         3         3          6
# 6   2025-11-13             Miami Heat     0         3         3          6
# 7   2025-11-15  Golden State Warriors     3         3         3          6
# 8   2025-11-28          Chicago Bulls     1         2         2          4
# 9   2025-11-11     Los Angeles Lakers     3         2         2          4
# 10  2025-11-13          Chicago Bulls     1         2         2          4
# 11  2025-11-15     Los Angeles Lakers     3         2         2          4
# 12  2025-11-17             Miami Heat     0         2         2          4
# 13  2025-11-13        Milwaukee Bucks     1         2         2          4
# 14  2025-11-05        New York Knicks     0         2         2          4
# 15  2025-11-19         Denver Nuggets     2         3         1          4
# 16  2025-11-17         Denver Nuggets     2         3         1          4
# 17  2025-11-07         Boston Celtics     0         1         3          4
# 18  2025-11-11           Phoenix Suns     2         3         2          5
# 19  2025-11-19           Phoenix Suns     2         2         2          4
# 20  2025-11-17        Toronto Raptors     0         3         3          6
# 21  2025-11-19       Dallas Mavericks     1         3         1          4
# Saved as three_consecutive_violations.csv

# %% [markdown]
# The original schedule had 22 violates, meaning our new schedule (16 violations) have improved.

# %% [markdown]
# ### Check if time zones have improved

# %%
def build_team_games_from_schedule(schedule_df, tz_team):
    """
    schedule_df must have columns: date, home_team, away_team
    tz_team: dict mapping team -> time zone index
    """
    teams = list(tz_team.keys())
    team_games = {t: [] for t in teams}

    for _, row in schedule_df.iterrows():
        d = row["date"]
        home = row["home_team"]
        away = row["away_team"]

        # Home team plays in its own arena
        if home in teams:
            team_games[home].append({
                "date": d,
                "arena_team": home,
                "tz": tz_team[home]
            })

        # Away team plays in the home team's arena
        if away in teams:
            team_games[away].append({
                "date": d,
                "arena_team": home,
                "tz": tz_team[home]
            })

    # Sort each team's games by date
    for t in teams:
        team_games[t] = sorted(team_games[t], key=lambda x: x["date"])

    return team_games


def compute_tz_metrics(team_games):
    """
    team_games: dict team -> list of dicts with keys: date, arena_team, tz
    Returns summary metrics about time-zone jumps.
    """
    total_pair_jump = 0
    num_pairs = 0

    total_triple_sum = 0
    num_triples = 0

    num_triple_violations = 0  # sum_jumps >= 4

    for team, games in team_games.items():
        n = len(games)
        if n < 2:
            continue

        # Pair jumps (between consecutive games)
        for k in range(n - 1):
            tz1 = games[k]["tz"]
            tz2 = games[k + 1]["tz"]
            total_pair_jump += abs(tz2 - tz1)
            num_pairs += 1

        # Triple windows
        for k in range(n - 2):
            tz1 = games[k]["tz"]
            tz2 = games[k + 1]["tz"]
            tz3 = games[k + 2]["tz"]

            diff12 = abs(tz2 - tz1)
            diff23 = abs(tz3 - tz2)
            total = diff12 + diff23

            total_triple_sum += total
            num_triples += 1

            if total >= 4:
                num_triple_violations += 1

    avg_pair_jump = total_pair_jump / num_pairs if num_pairs > 0 else 0.0
    avg_triple_sum = total_triple_sum / num_triples if num_triples > 0 else 0.0

    return {
        "avg_pair_jump": avg_pair_jump,
        "avg_triple_sum": avg_triple_sum,
        "num_triple_violations": num_triple_violations,
    }

# %%
# Make sure original df is sorted and has date, home_team, away_team
df = df.sort_values("date").reset_index(drop=True)

# Build team game sequences for original schedule
orig_team_games = build_team_games_from_schedule(
    df[["date", "home_team", "away_team"]],
    tz_team
)
orig_metrics = compute_tz_metrics(orig_team_games)

# Build team game sequences for optimized schedule
opt_team_games = build_team_games_from_schedule(
    schedule_df[["date", "home_team", "away_team"]],
    tz_team
)
opt_metrics = compute_tz_metrics(opt_team_games)

print("=== Time-zone metrics comparison ===")
print("Original schedule:")
for k, v in orig_metrics.items():
    print(f"  {k}: {v}")

print("\nOptimized schedule:")
for k, v in opt_metrics.items():
    print(f"  {k}: {v}")

print("\nDifferences (optimized - original):")
for k in orig_metrics:
    diff = opt_metrics[k] - orig_metrics[k]
    print(f"  {k}: {diff}")
# Out:
# === Time-zone metrics comparison ===
# Original schedule:
#   avg_pair_jump: 0.8333333333333334
#   avg_triple_sum: 1.5803571428571428
#   num_triple_violations: 22
#
# Optimized schedule:
#   avg_pair_jump: 0.8
#   avg_triple_sum: 1.5267857142857142
#   num_triple_violations: 16
#
# Differences (optimized - original):
#   avg_pair_jump: -0.033333333333333326
#   avg_triple_sum: -0.0535714285714286
#   num_triple_violations: -6
